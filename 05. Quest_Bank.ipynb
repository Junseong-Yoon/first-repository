# %%
import random

class Account :

  count = 0

  def __init__ (self, customer, money):
    self.customer = customer
    self.money = int(money)
    self.deposit_count = 0

    self.A=random.randint(100,999)        #100~999 사이 정수
    self.B=random.randint(10, 99)         #10~99 사이 정수
    self.C=random.randint(100000, 999999) #100000~999999 사이 정수

    #초기화되는 생성자.
    self.account_number = f"{self.A}-{self.B}-{self.C}"

    Account.count += 1

    self.deposit_history=[]
    self.withdrawal_history=[]

  def get_account_num(self):
    print(f"현재 계좌 수: {Account.count}")

  def info(self):
    print('예금주 :',self.customer, '잔액 :',self.money,'SC은행', self.account_number)




  #입금메서드
  def deposit(self, money):   #money에 받은 값을 self.money에 더해야하고 최소 1원 이상이여야함.

    money = int(money)
    if money > 0 :
      self.money = int(self.money) + money
      print(f"{money}원 입금 //{self.customer} 잔액 : {self.money}원")
      self.deposit_count += 1

      self.deposit_history.append(money)

      if self.deposit_count % 5 == 0 :
        rate = int(self.money * 0.01)
        self.money = self.money + rate
        print(f"입금 5회 이상되어 1% 이자지급{rate} 총 잔액{self.money}")

    else:
      print("0원 이상을 기입하세요")



  #출금메서드
  def withdraw(self, money):
    money = int(money)
    if self.money >= money:
      self.money = int(self.money) - money
      print(f"{money}원 출금 //{self.customer} 잔액 : {self.money}원")

      self.withdrawal_history.append(money)

    else:
      print("잔액보다 큰 값을 입력할 수 없습니다.")


  #잔액을 보여주는 메서드
  def display_info(self):
    print(f"은행이름: SC은행, 예금주:{self.customer}, 계좌번호:{self.account_number}, 잔고: {int(self.money):,}원")

  #history를 출력하는 함수
  def result(self):
    print(f"{self.customer} 입출금내역")
    print("입금내역:",self.deposit_history[0:])
    print("출금내역:",self.withdrawal_history[0:])


#self를 받아서인자를 받을때 다 초기화

first = Account('윤준성', '10000000')
second = Account('김희철', '50000')
third = Account('박명수', '70000')

accounts=[first, second, third]

print("\n1. 계좌 정보")
first.info()
second.info()

print("\n2. 입금")
first.deposit('7000')
second.deposit('10000')

print("\n3. 출금")
first.withdraw('1000')
second.withdraw('30000')

print("\n4. 잔액 정보")
first.display_info()
second.display_info()

print("\n5. 5회입금마다 이자 1%")
first.deposit('3000')
first.deposit('3000')
first.deposit('3000')
first.deposit('3000')

print("\n6. 100만원 이상 고객")
for account in accounts:
    if int(account.money) >= 1000000:
        account.display_info()

print("\n7. 입출금내역 출력")
for account in accounts:
    account.result()

print("\n8. 계좌의 갯수")
first.get_account_num()
# Out:
# 1. 계좌 정보
# 예금주 : 윤준성 잔액 : 10000000 SC은행 372-28-962694
# 예금주 : 김희철 잔액 : 50000 SC은행 977-96-599298
#
# 2. 입금
# 7000원 입금 //윤준성 잔액 : 10007000원
# 10000원 입금 //김희철 잔액 : 60000원
#
# 3. 출금
# 1000원 출금 //윤준성 잔액 : 10006000원
# 30000원 출금 //김희철 잔액 : 30000원
#
# 4. 잔액 정보
# 은행이름: SC은행, 예금주:윤준성, 계좌번호:372-28-962694, 잔고: 10,006,000원
# 은행이름: SC은행, 예금주:김희철, 계좌번호:977-96-599298, 잔고: 30,000원
#
# 5. 5회입금마다 이자 1%
# 3000원 입금 //윤준성 잔액 : 10009000원
# 3000원 입금 //윤준성 잔액 : 10012000원
# 3000원 입금 //윤준성 잔액 : 10015000원
# 3000원 입금 //윤준성 잔액 : 10018000원
# 입금 5회 이상되어 1% 이자지급100180 총 잔액10118180
#
# 6. 100만원 이상 고객
# 은행이름: SC은행, 예금주:윤준성, 계좌번호:372-28-962694, 잔고: 10,118,180원
#
# 7. 입출금내역 출력
# 윤준성 입출금내역
# 입금내역: [7000, 3000, 3000, 3000, 3000]
# 출금내역: [1000]
# 김희철 입출금내역
# 입금내역: [10000]
# 출금내역: [30000]
# 박명수 입출금내역
# 입금내역: []
# 출금내역: []
#
# 8. 계좌의 갯수
# 현재 계좌 수: 3

# %%
#1. 은행에 가서 계좌를 개설하면 은행이름, 예금주, 계좌번호, 잔액이 설정됩니다. Account 클래스를 생성한 후 생성자(hint: 매직메서드..!!)를 구현해보세요. 생성자에서는 예금주와 초기 잔액만 입력 받습니다. 
#계좌계설 메서드를 만들고 은행이름은 SC은행으로 계좌번호는 3자리-2자리-6자리 형태로 랜덤하게 생성되도록 합니다. (은행이름: SC은행, 계좌번호: 111-11-111111)

#2클래스 변수를 사용해서 Account 클래스로부터 생성된 계좌 객체의 개수를 저장하세요.

#3 Account 클래스로부터 생성된 계좌의 개수를 출력하는 get_account_num() 메서드를 추가하세요.

#4 Account 클래스에 입금을 위한 deposit 메서드를 추가하세요. 입금은 최소 1원 이상만 가능합니다.

#5 Account 클래스에 출금을 위한 withdraw 메서드를 추가하세요. 출금은 계좌의 잔고 이상으로 출금할 수는 없습니다.

#6 Account 인스턴스에 저장된 정보를 출력하는 display_info() 메서드를 추가하세요. 잔고는 세자리마다 쉼표를 출력하세요.(은행이름: SC은행, 예금주: 파이썬, 계좌번호: 111-11-111111, 잔고: 10,000원)

#7 입금 횟수가 5회가 될 때 잔고를 기준으로 1%의 이자가 잔고에 추가되도록 코드를 변경해보세요.

#8 Account 클래스로부터 3개 이상 인스턴스를 생성하고 생성된 인스턴스를 리스트에 저장해보세요.

#9 객체 순회 반복문을 통해 리스트에 있는 객체를 순회하면서 잔고가 100만원 이상인 고객의 정보만 출력하세요.

#10 입금과 출금 내역이 기록되도록 코드를 업데이트 하세요. (입금 내역과 출금 내역을 출력하는 deposit history와 withdrawal history 메서드를 추가하세요.)
